# %%
# prompt: !ls /content/drive/

import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.18.0

# %%
# prompt: !ls /content/drive/MyDrive/

import tensorflow as tf

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.18.0
