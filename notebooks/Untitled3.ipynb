# %%
import os

# استعراض جميع الملفات داخل Google Colab
files = os.listdir("/content")

print("\n📁 الملفات المتاحة داخل Google Colab:\n")
for file in files:
    print(file)
# Out:
# 📁 الملفات المتاحة داخل Google Colab:
